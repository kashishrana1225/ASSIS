# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Step 1: URL (can be changed to what your faculty provides)
url = "http://quotes.toscrape.com"

# Step 2: Fetch webpage
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")

    # Step 3: Extract quotes and authors
    quotes = soup.find_all("span", class_="text")
    authors = soup.find_all("small", class_="author")

    # Store data in lists
    data = []
    for i in range(len(quotes)):
        data.append({
            "Author": authors[i].text,
            "Quote": quotes[i].text
        })

    # Step 4: Convert to DataFrame
    df = pd.DataFrame(data)

    # Step 5: Save to Excel
    df.to_excel("quotes.xlsx", index=False)

    print("Scraping completed ✅ Quotes saved to 'quotes.xlsx'")
else:
    print("Failed to retrieve webpage. Status code:", response.status_code)
# Out:
# Scraping completed ✅ Quotes saved to 'quotes.xlsx'
